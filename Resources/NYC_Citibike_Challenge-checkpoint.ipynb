# %%
import pandas as pd
from datetime import datetime
import os

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
citi_bike_to_load = "resources/201908-citibike-tripdata2.csv"
citi_bike_df = pd.read_csv(citi_bike_to_load)

# %%
# 2. Check the datatypes of your columns. 
citi_bike_df.head(5)
# Out:
#    Birth Year              End Station Name   Gender  \
# 0        1969           Bond St & Fulton St  Unknown
# 1        1969             1 Pl & Clinton St  Unknown
# 2        1969         Carlton Ave & Dean St  Unknown
# 3        1969  St Johns Pl & Washington Ave  Unknown
# 4        1969     Wyckoff Av & Jefferson St  Unknown
#
#               Start Station Name             Starttime              Stoptime  \
# 0  Cadman Plaza E & Red Cross Pl  8/22/2019 9:17:15 PM  8/22/2019 9:32:55 PM
# 1  Cadman Plaza E & Red Cross Pl  8/22/2019 7:08:09 PM  8/22/2019 7:20:32 PM
# 2  Cadman Plaza E & Red Cross Pl  8/24/2019 1:52:20 PM  8/24/2019 2:16:18 PM
# 3  Cadman Plaza E & Red Cross Pl  8/22/2019 5:12:43 PM  8/22/2019 5:37:59 PM
# 4  Cadman Plaza E & Red Cross Pl  8/24/2019 6:19:35 PM  8/24/2019 6:55:17 PM
#
#    Usertype  Bikeid  End Station Id  End Station Latitude  \
# 0  Customer   27666          3232.0             40.689622
# 1  Customer   18580          3386.0             40.680959
# ...

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citi_bike_df['Tripduration'] = pd.to_datetime(citi_bike_df['Tripduration'], unit = 's')
citi_bike_df.head(5)
# Out:
#    Birth Year              End Station Name   Gender  \
# 0        1969           Bond St & Fulton St  Unknown
# 1        1969             1 Pl & Clinton St  Unknown
# 2        1969         Carlton Ave & Dean St  Unknown
# 3        1969  St Johns Pl & Washington Ave  Unknown
# 4        1969     Wyckoff Av & Jefferson St  Unknown
#
#               Start Station Name             Starttime              Stoptime  \
# 0  Cadman Plaza E & Red Cross Pl  8/22/2019 9:17:15 PM  8/22/2019 9:32:55 PM
# 1  Cadman Plaza E & Red Cross Pl  8/22/2019 7:08:09 PM  8/22/2019 7:20:32 PM
# 2  Cadman Plaza E & Red Cross Pl  8/24/2019 1:52:20 PM  8/24/2019 2:16:18 PM
# 3  Cadman Plaza E & Red Cross Pl  8/22/2019 5:12:43 PM  8/22/2019 5:37:59 PM
# 4  Cadman Plaza E & Red Cross Pl  8/24/2019 6:19:35 PM  8/24/2019 6:55:17 PM
#
#    Usertype  Bikeid  End Station Id  End Station Latitude  \
# 0  Customer   27666          3232.0             40.689622
# 1  Customer   18580          3386.0             40.680959
# ...

# %%
# 4. Check the datatypes of your columns. 
citi_bike_df.dtypes
# Out:
# Birth Year                          int64
# End Station Name                   object
# Gender                             object
# Start Station Name                 object
# Starttime                          object
# Stoptime                           object
# Usertype                           object
# Bikeid                              int64
# End Station Id                    float64
# End Station Latitude              float64
# End Station Longitude             float64
# Rideduration                        int64
# Start Station Id                  float64
# Start Station Latitude            float64
# Start Station Longitude           float64
# Tripduration               datetime64[ns]
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citi_bike_df.to_csv('resources/citibike_challenge.csv', index=False)
